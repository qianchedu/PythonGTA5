# %%
#800*600分辨率
import numpy as np
from PIL import ImageGrab
import cv2
import time
import pyautogui
from numpy import ones,vstack
from numpy.linalg import lstsq
from directkeys import ReleaseKey,PressKey,W,A,S,D
from statistics import mean

def draw_lines(img,lines):
    try:
        for line in lines:
            #[[[2,2,6,2]]
            coords = line[0]
            cv2.line(img,(coords[0],coords[1]),(coords[2],coords[3]),[255,255,255],3)
    except:
        pass



def roi(img,vertices):
    mask = np.zeros_like(img)
    cv2.fillPoly(mask,vertices,255)
    masked = cv2.bitwise_and(img,mask)
    return masked
    

def draw_lanes(img,lines,color=[0,255,255],thickness = 3):
    try:
        ys = []
        
        for i in lines:
            for ii in i:
                ys+=[ii[1],ii[3]]
        
        min_y = min(ys)
        max_y = 600
        
        new_lines = []
        line_dict = {}
        
        for idx,i in enumerate(lines):
            for xyxy in i:
                x_coords = (xyxy[0],xyxy[2])
                y_coords = (xyxy[1],xyxy[3])
                A = vstack([X_COORDS,ONES(len(x_coords))]).T
                m,b = lstsq(A,y_coords)[0]
                
                x1 = (min_y - b)/m
                x2 = (max_y - b)/m
                
                line_dict[idx] = [m,b,[int(x1),min_y,int(x2),max_y]]
                new_lines.append([int(x1),min_y,int(x2),max_y])
                
                
        final_lanes = {}
        
        for idx in line_dict:
            final_lanes_copy = final_lanes.copy()
            m = line_dict[idx][0]
            b = line_dict[idx][1]
            line = line_dict[idx][2]
            
            if len(final_lanes) == 0:
                final_lanes[m] = [[m,b,line]]
            else:
                found_copy = False
                
                for other_ms in final_lanes_copy:
                    if not found_copy:
                        if abs(other_ms*1.1) > abs(m) > abs(other_ms*0.9):
                            if abs(final_lanes_copy[other_ms][0][1]*1.1) > abs(b) > abs(final_lanes_copy[other_ms][0][1]*0.9):
                                final_lanes[other_ms].append([m,b,line])
                                found_copy = True
                                break
                                
                        else:
                            final_lanes[m] = [[m,b,line]]
        
        line_counter = {}
        
        for lanes in final_lanes:
            line_counter[lanes] = len(final_lanes[lanes])
            
        top_lanes = sorted(line_counter.items(),key=lambda item:item[1])[::-1][::2]
        
        lane1_id = top_lanes[0][0]
        lane2_id = top_lanes[1][0]
        
        def average_lane(lane_data):
            x1s = []
            x2s = []
            y1s = []
            y2s = []
            
            for data in lane_data:
                x1s.append(data[2][0])
                y1s.append(data[2][1])
                x2s.append(data[2][2])
                y2s.append(data[2][3])
                
            return int(mean(x1s)),int(mean(y1s)),int(mean(x2s)),int(mean(y2s))
        
        
        l1_x1,l1_y1,l1_x2,l1_y2 = average_lane(final_lanes[lane1_id])
        l2_x1,l2_y2,l2_x2,l2_y2 = average_lane(final_lanes[lane2_id])
        
        return [l1_x1,l1_y1,l1_x2,l1_y2],[l2_x1,l2_y2,l2_x2,l2_y2],lane1_id,lane2_id
        
                                
    except Exception as e:
        print(str(e))
                                
                            
                
    
    
def process_img(image):
    original_image = image
    
    processed_img = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
    processed_img = cv2.Canny(processed_img,threshold1 = 200,threshold2=300)
    
    processed_img = cv2.GaussianBlur(processed_img,(5,5),0)
    
    vertices = np.array([[10,500],[10,300],[300,200],[500,200],[800,300],[800,500],],np.int32)
    processed_img = roi(processed_img,[vertices])
    
    lines = cv2.HoughLinesP(processed_img,1,np.pi/180,180,np.array([]),100,5)
    m1 = 0
    m2 = 0
    try:
        l1,l2,m2,m3 = draw_lanes(original_image,lines)
        cv2.line(original_image,(l1[0],l1[1]),(l1[2],l1[3]),[0,255,0],30)
        cv2.line(original_image,(l2[0],l2[1]),(l2[2],l2[3]),[0,255,0],30)
        
    except Exception as e:
        print(str(e))
        pass
    
    try:
        for coords in lines:
            coords = coords[0]
            try:
                cv2.line(processed_img,(coords[0],coords[1]),(coords[2],coords[3]),[0,255,0],30)
                
            except Exception as e:
                print(str(e))
    except Exception as e:
        pass

    return processed_img,original_image,m1,m2
    

def straight():
    print('straight')
    PressKey(W)
    ReleaseKey(A)
    ReleaseKey(D)
    
def left():
    print('left')
    PressKey(A)
    ReleaseKey(W)
    ReleaseKey(D)
    ReleaseKey(A)
    
def right():
    print('right')
    PressKey(D)
    ReleaseKey(A)
    ReleaseKey(W)
    ReleaseKey(D)
    
    
    

def slow_ya_roll():
    print('slow_ya_roll')
    ReleaseKey(W)
    ReleaseKey(A)
    ReleaseKey(D)
    
    
for i in list(range(4))[::-1]:
    print(i+1)
    time.sleep(1)

# for i in list(range(4))[::-1]:
#     print(i+1)
#     time.sleep(1)
    
    
# print('down')
# pyautogui.keyDown('w')
# time.sleep(3)
# print('up')
# pyautogui.keyUp('w')  


last_time = time.time()
while True:
    screen =np.array(ImageGrab.grab(bbox=(0,40,800,640)))
  #  new_screen = process_img(screen)


#     print('down')
#     PressKey(W)
#     time.sleep(3)
#     print('up')
#     ReleaseKey(W)
    #printscreen_numpy = np.array(printscreen_pil.getdata(),dtype='uint8')

    print('look took {} seconds'.format(time.time() - last_time))
    last_time = time.time()
    new_screen,original_image,m1,m2 = process_img(screen)
    #cv2.imshow('window',np.array(printscreen_pil))
 #   cv2.imshow('window',new_screen)
    cv2.imshow('window2',cv2.cvtColor(original_image,cv2.COLOR_BGR2RGB))

    if m1 < 0 and m2 < 0:
        right()
    elif m1 > 0 and m2 > 0:
        left()
    else:
        straight()

    if cv2.waitKey(25) & 0xFF == ord('q'):
        cv2.destroyAllWindows()
        break
    
#main()
# Out:
# 4
# 3
# 2
# 1
# look took 0.07901716232299805 seconds
# name 'X_COORDS' is not defined
# cannot unpack non-iterable NoneType object
# straight
# look took 0.11402630805969238 seconds
# name 'X_COORDS' is not defined
# cannot unpack non-iterable NoneType object
# straight
# look took 0.09702277183532715 seconds
# name 'X_COORDS' is not defined
# cannot unpack non-iterable NoneType object
# straight
# look took 0.08101773262023926 seconds
# name 'X_COORDS' is not defined
# cannot unpack non-iterable NoneType object
# straight
# look took 0.10302352905273438 seconds
# name 'X_COORDS' is not defined
# cannot unpack non-iterable NoneType object
# straight
# look took 0.08101749420166016 seconds
# name 'X_COORDS' is not defined
# cannot unpack non-iterable NoneType object
# straight
# look took 0.08201861381530762 seconds
# name 'X_COORDS' is not defined
# cannot unpack non-iterable NoneType object
# straight
# look took 0.09002113342285156 seconds
# name 'X_COORDS' is not defined
# cannot unpack non-iterable NoneType object
# straight
# look took 0.07801699638366699 seconds
# name 'X_COORDS' is not defined
# cannot unpack non-iterable NoneType object
# straight
# look took 0.13203144073486328 seconds
# name 'X_COORDS' is not defined
# cannot unpack non-iterable NoneType object
# straight
# look took 0.11802506446838379 seconds
# name 'X_COORDS' is not defined
# cannot unpack non-iterable NoneType object
# straight
# look took 0.09702181816101074 seconds
# name 'X_COORDS' is not defined
# cannot unpack non-iterable NoneType object
# straight
# look took 0.13403058052062988 seconds
# name 'X_COORDS' is not defined
# cannot unpack non-iterable NoneType object
# straight
# look took 0.1000220775604248 seconds
# name 'X_COORDS' is not defined
# cannot unpack non-iterable NoneType object
# straight
# look took 0.13102984428405762 seconds
# name 'X_COORDS' is not defined
# cannot unpack non-iterable NoneType object
# straight
# look took 0.08401918411254883 seconds
# name 'X_COORDS' is not defined
# cannot unpack non-iterable NoneType object
# straight
# look took 0.0800180435180664 seconds
# name 'X_COORDS' is not defined
# cannot unpack non-iterable NoneType object
# straight
# look took 0.14403247833251953 seconds
# name 'X_COORDS' is not defined
# cannot unpack non-iterable NoneType object
# straight
# look took 0.09302091598510742 seconds
# name 'X_COORDS' is not defined
# cannot unpack non-iterable NoneType object
# straight
# look took 0.10002279281616211 seconds
# name 'X_COORDS' is not defined
# cannot unpack non-iterable NoneType object
# straight
# look took 0.